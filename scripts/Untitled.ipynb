# %%
from pyaedt import Hfss

# Launch HFSS and create a new project
hfss = Hfss()

# Load an existing project
project_path = r"C:\path_to_your_project\your_project.aedt"  # Replace with your project path
hfss.load_project(project_path)

# Set the active design
hfss.set_active_design("Your_Design_Name")  # Replace with your design name

# Define or modify parameters
hfss["Wire_Diameter"] = "20um"
hfss["Coil_Pad_Size"] = "500um"
hfss["Enclosed_Area"] = "100um"

# Modify the width of all polylines to 20 um
for obj in hfss.modeler.objects:
    if hfss.modeler.objects[obj].object_type == "Polyline":
        hfss.modeler.change_property(
            [
                "NAME:AllTabs",
                [
                    "NAME:Geometry3DAttributeTab",
                    [
                        "NAME:PropServers", obj
                    ],
                    [
                        "NAME:ChangedProps",
                        [
                            "NAME:Width",
                            "Value:=", "20um"
                        ]
                    ]
                ]
            ]
        )

# Set up a simulation
setup = hfss.create_setup(setupname="Setup1")
setup.props["Frequency"] = "1GHz"
setup.props["MaximumPasses"] = 10
setup.props["MinimumPasses"] = 2
setup.props["MaxDeltaS"] = 0.02
setup.update()

# Run the simulation
hfss.analyze_setup("Setup1")

# Export results
report = hfss.post.create_report("Inductance", "Setup1", "Rectangular Plot")
report.export_to_file("inductance.csv")

# Save the project
hfss.save_project()

# Release the HFSS instance
hfss.release_desktop()
# Out:
# PyAEDT INFO: Initializing new Desktop session.
# PyAEDT INFO: StdOut is enabled
# PyAEDT INFO: Log on file is enabled
# PyAEDT INFO: Log on Desktop Message Manager is enabled
# PyAEDT INFO: Debug logger is disabled. PyAEDT methods will not be logged.
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 4, in <module>
# PyAEDT ERROR:     hfss = Hfss()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\hfss.py", line 216, in __init__
# PyAEDT ERROR:     FieldAnalysis3D.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Analysis3D.py", line 106, in __init__
# PyAEDT ERROR:     Analysis.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Analysis.py", line 143, in __init__
# PyAEDT ERROR:     Design.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 262, in __init__
# PyAEDT ERROR:     self._desktop_class = _init_desktop_from_design(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\desktop.py", line 409, in _init_desktop_from_design
# PyAEDT ERROR:     return Desktop(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\desktop.py", line 593, in __init__
# PyAEDT ERROR:     student_version_flag, version_key, version = self._assert_version(version, student_version)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\desktop.py", line 884, in _assert_version
# PyAEDT ERROR:     raise ValueError(
# PyAEDT ERROR: Specified version 2023.2 is not installed on your system on __init__
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 4, in <module>
# PyAEDT ERROR:     hfss = Hfss()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\hfss.py", line 216, in __init__
# PyAEDT ERROR:     FieldAnalysis3D.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Analysis3D.py", line 106, in __init__
# PyAEDT ERROR:     Analysis.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Analysis.py", line 143, in __init__
# PyAEDT ERROR:     Design.__init__(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 262, in __init__
# PyAEDT ERROR:     self._desktop_class = _init_desktop_from_design(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\desktop.py", line 409, in _init_desktop_from_design
# PyAEDT ERROR:     return Desktop(*args, **kwargs)
# PyAEDT ERROR: __init__() should return none, not 'bool' on __init__
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 8, in <module>
# PyAEDT ERROR:     hfss.load_project(project_path)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 2621, in load_project
# PyAEDT ERROR:     proj = self.odesktop.OpenProject(file_name)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 505, in odesktop
# PyAEDT ERROR:     return self._desktop
# PyAEDT ERROR: 'hfss' object has no attribute '_desktop' on load_project
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     file_name = C:\path_to_your_project\your_project.aedt
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 11, in <module>
# PyAEDT ERROR:     hfss.set_active_design("Your_Design_Name")  # Replace with your design name
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 3858, in set_active_design
# PyAEDT ERROR:     self._init_design(project_name=self.project_name, design_name=name)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 725, in project_name
# PyAEDT ERROR:     if self.oproject:
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 1147, in oproject
# PyAEDT ERROR:     return self._oproject
# PyAEDT ERROR: 'hfss' object has no attribute '_oproject' on set_active_design
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     name = Your_Design_Name
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 14, in <module>
# PyAEDT ERROR:     hfss["Wire_Diameter"] = "20um"
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 193, in __setitem__
# PyAEDT ERROR:     self.variable_manager[variable_name] = variable_value
# PyAEDT ERROR: 'nonetype' object does not support item assignment on __setitem__
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     variable_name = Wire_Diameter
# PyAEDT ERROR:     variable_value = 20um
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 15, in <module>
# PyAEDT ERROR:     hfss["Coil_Pad_Size"] = "500um"
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 193, in __setitem__
# PyAEDT ERROR:     self.variable_manager[variable_name] = variable_value
# PyAEDT ERROR: 'nonetype' object does not support item assignment on __setitem__
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     variable_name = Coil_Pad_Size
# PyAEDT ERROR:     variable_value = 500um
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 196, in _run_module_as_main
# PyAEDT ERROR:     return _run_code(code, main_globals, None,
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\runpy.py", line 86, in _run_code
# PyAEDT ERROR:     exec(code, run_globals)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# PyAEDT ERROR:     app.launch_new_instance()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# PyAEDT ERROR:     app.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# PyAEDT ERROR:     self.io_loop.start()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# PyAEDT ERROR:     self.asyncio_loop.run_forever()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 603, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\base_events.py", line 1906, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "C:\Program Files\AnsysEM\Ansys Student\v232\Win64\commonfiles\CPython\3_10\winx64\Release\python\lib\asyncio\events.py", line 80, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# PyAEDT ERROR:     await self.process_one()
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# PyAEDT ERROR:     await dispatch(*args)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# PyAEDT ERROR:     await result
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# PyAEDT ERROR:     await super().execute_request(stream, ident, parent)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# PyAEDT ERROR:     reply_content = await reply_content
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# PyAEDT ERROR:     res = shell.run_cell(
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# PyAEDT ERROR:     return super().run_cell(*args, **kwargs)
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Local\Temp\ipykernel_14540\1275159875.py", line 16, in <module>
# PyAEDT ERROR:     hfss["Enclosed_Area"] = "100um"
# PyAEDT ERROR:   File "C:\Users\go29lap\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py", line 193, in __setitem__
# PyAEDT ERROR:     self.variable_manager[variable_name] = variable_value
# PyAEDT ERROR: 'nonetype' object does not support item assignment on __setitem__
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     variable_name = Enclosed_Area
# PyAEDT ERROR:     variable_value = 100um
# PyAEDT ERROR: **************************************************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 19
#      16 hfss["Enclosed_Area"] = "100um"
#      18 # Modify the width of all polylines to 20 um
# ---> 19 for obj in hfss.modeler.objects:
#      20     if hfss.modeler.objects[obj].object_type == "Polyline":
#      21         hfss.modeler.change_property(
#      22             [
#      23                 "NAME:AllTabs",
#    (...)
#      37             ]
#      38         )
#
# File ~\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Analysis3D.py:152, in FieldAnalysis3D.modeler(self)
#     144 """Modeler.
#     145
#     146 Returns
#    (...)
#     149     Modeler object.
#     150 """
#     151 if self._modeler is None:
# --> 152     self.logger.reset_timer()
#     154     from pyaedt.modeler.modeler2d import Modeler2D
#     155     from pyaedt.modeler.modeler3d import Modeler3D
#
# File ~\AppData\Roaming\.pyaedt_env\3_10\lib\site-packages\pyaedt\application\Design.py:536, in Design.logger(self)
#     528 @property
#     529 def logger(self):
#     530     """Logger for the design.
#     531
#     532     Returns
#     533     -------
#     534     :class:`pyaedt.aedt_logger.AedtLogger`
#     535     """
# --> 536     return self._logger
#
# AttributeError: 'Hfss' object has no attribute '_logger'
